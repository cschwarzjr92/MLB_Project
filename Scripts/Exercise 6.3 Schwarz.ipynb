# %% [markdown]
# # This script contains:
#
# 1. Import Libraries and Data
# 2. Wrangling & Cleaning
# 3. Create Chloropleth of attendance 2015-2024
# 4. Create chloropleth of pre-covid attendance
# 5. Create chloropleth of post-covid attendance
# 6. Analysis

# %% [markdown]
# ### Import Libraries & Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import json
import folium

# %%
# Import JSON file
geo = "C:\\Users\\cschw\\OneDrive\\Desktop\\MLB Project\\Achievement 6\\6.3\\us-states.json"

# %%
geo
# Out:
# 'C:\\Users\\cschw\\OneDrive\\Desktop\\MLB Project\\Achievement 6\\6.3\\us-states.json'

# %%
# Define Path
path = path = r"C:\Users\cschw\OneDrive\Desktop\MLB Project\Data Sets\Other Data"

# %%
# Upload attendance by state csv
att_df = pd.read_csv(f"{path}\\Attendance by state 2015-2024.csv")

# %%
att_df.head()
# Out:
#                   State  Attendance/Game
# 0               Arizona      24039.66667
# 1            California      32178.77778
# 2              Colorado      32533.55556
# 3  District of Columbia      27137.44444
# 4               Florida      14629.55556

# %%
# Upload pre covid attendance csv
pre_df = pd.read_csv(f"{path}\\pre covid attendance by state.csv")

# %%
pre_df.head()
# Out:
#                   State  Attendance/Game
# 0               Arizona         26244.20
# 1            California         34342.48
# 2              Colorado         34746.00
# 3  District of Columbia         30657.40
# 4               Florida         15885.20

# %%
# Upload post covid attendance csv
post_df = pd.read_csv(f"{path}\\post covid attendance by state.csv")

# %%
post_df.head()
# Out:
#                   State  Attendance/Game
# 0               Arizona         21284.00
# 1            California         29474.15
# 2              Colorado         29768.00
# 3  District of Columbia         22737.50
# 4               Florida         13060.00

# %% [markdown]
# ### Wrangling & Cleaning

# %% [markdown]
# Due to the simplicity of the data needed for these maps and for efficieny's sake I created pivot tables in excel to aggregate the data for each state.  The only additional cleaning step necessary was to remove the year 2020 from the 2015-2024 attendance file. This was important because attendance was 0 that year due to the pandemic. For the purpose of evaluating long term trends in attendance, and how the pandemic impacted attendance, I removed 2020 from the data set that includes all of the last 10 years.  Then I created the CSV files uploaded above so that I can create seperate maps to show change over time. Finally, I changed the name of the State column into 'STATE_NAME' to match with the json file

# %%
# Change State column for att_df
att_df.rename(columns={'State': 'STATE_NAME'}, inplace=True)

# %%
att_df.head()
# Out:
#              STATE_NAME  Attendance/Game
# 0               Arizona      24039.66667
# 1            California      32178.77778
# 2              Colorado      32533.55556
# 3  District of Columbia      27137.44444
# 4               Florida      14629.55556

# %%
# change State column for pre_df
pre_df.rename(columns={'State': 'STATE_NAME'}, inplace=True)

# %%
pre_df.head()
# Out:
#              STATE_NAME  Attendance/Game
# 0               Arizona         26244.20
# 1            California         34342.48
# 2              Colorado         34746.00
# 3  District of Columbia         30657.40
# 4               Florida         15885.20

# %%
#change the state column for post_df
post_df.rename(columns={'State': 'STATE_NAME'}, inplace=True)

# %%
post_df.head()
# Out:
#              STATE_NAME  Attendance/Game
# 0               Arizona         21284.00
# 1            California         29474.15
# 2              Colorado         29768.00
# 3  District of Columbia         22737.50
# 4               Florida         13060.00

# %% [markdown]
# ### Create Cloropleth map of Attendance per Game 2015-2024

# %%
map = folium.Map(location=[40, -95], zoom_start=4)

folium.Choropleth(
    geo_data=geo, 
    data=att_df,
    columns=['STATE_NAME', 'Attendance/Game'],
    key_on='feature.properties.name',
    fill_color='Blues',  # Changed color scheme to blue
    fill_opacity=0.7,  # Increased opacity for better distinction
    line_opacity=0.2,  # Increased line opacity slightly
    nan_fill_color='lightgrey',  # States with no data will appear light grey
    nan_fill_opacity=0.4,  # Light grey slightly transparent
    legend_name="Attendance/Game"
).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_247e7ecdfed9951703be43bfaff330f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_247e7ecdfed9951703be43bfaff330f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_247e7ecdfed9951703be43bfaff330f9 = L.map(
#                 &quot;map_247e7ecdfed9951703be43bfaff330f9&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3cd268319418f07dcc00ac1da86398b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c3cd268319418f07dcc00ac1da86398b.addTo(map_247e7ecdfed9951703be43bfaff330f9);
#
#
#             var choropleth_334825a678b449e15e9a26fd5c215fd4 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_bba72d25e1b1b8751cf4e90e9a4bace1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MS&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;OR&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;lightgrey&quot;, &quot;fillOpacity&quot;: 0.4, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;MD&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;OH&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CO&quot;: case &quot;GA&quot;: case &quot;MA&quot;: case &quot;MO&quot;: case &quot;NY&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;IL&quot;: case &quot;TX&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_bba72d25e1b1b8751cf4e90e9a4bace1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bba72d25e1b1b8751cf4e90e9a4bace1 = L.geoJson(null, {
#                 onEachFeature: geo_json_bba72d25e1b1b8751cf4e90e9a4bace1_onEachFeature,
#
#                 style: geo_json_bba72d25e1b1b8751cf4e90e9a4bace1_styler,
#         });
#
#         function geo_json_bba72d25e1b1b8751cf4e90e9a4bace1_add (data) {
#             geo_json_bba72d25e1b1b8751cf4e90e9a4bace1
#                 .addData(data);
#         }
#             geo_json_bba72d25e1b1b8751cf4e90e9a4bace1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot

# %% [markdown]
# ### Create chloropleth map of Pre-Covid Attendance

# %%
map = folium.Map(location=[40, -95], zoom_start=4)

folium.Choropleth(
    geo_data=geo, 
    data=pre_df,
    columns=['STATE_NAME', 'Attendance/Game'],
    key_on='feature.properties.name',
    fill_color='Blues',  # Changed color scheme to blue
    fill_opacity=0.7,  # Increased opacity for better distinction
    line_opacity=0.2,  # Increased line opacity slightly
    nan_fill_color='lightgrey',  # States with no data will appear light grey
    nan_fill_opacity=0.4,  # Light grey slightly transparent
    legend_name="Attendance/Game"
).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f33e08f983ee3e5cb05f49066e60c24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f33e08f983ee3e5cb05f49066e60c24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f33e08f983ee3e5cb05f49066e60c24 = L.map(
#                 &quot;map_0f33e08f983ee3e5cb05f49066e60c24&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84cc7129dfbf87b7e800ea879a989e59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_84cc7129dfbf87b7e800ea879a989e59.addTo(map_0f33e08f983ee3e5cb05f49066e60c24);
#
#
#             var choropleth_5e6b0d0d8bcdd65c0aa94cf93feac75e = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_2108b9418b0565fd03df19a189952e04_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MS&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;OR&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;lightgrey&quot;, &quot;fillOpacity&quot;: 0.4, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;GA&quot;: case &quot;MI&quot;: case &quot;WA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CO&quot;: case &quot;MA&quot;: case &quot;MO&quot;: case &quot;NY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;IL&quot;: case &quot;TX&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2108b9418b0565fd03df19a189952e04_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2108b9418b0565fd03df19a189952e04 = L.geoJson(null, {
#                 onEachFeature: geo_json_2108b9418b0565fd03df19a189952e04_onEachFeature,
#
#                 style: geo_json_2108b9418b0565fd03df19a189952e04_styler,
#         });
#
#         function geo_json_2108b9418b0565fd03df19a189952e04_add (data) {
#             geo_json_2108b9418b0565fd03df19a189952e04
#                 .addData(data);
#         }
#             geo_json_2108b9418b0565fd03df19a189952e04_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;i

# %% [markdown]
# ### Create chloropleth map of post-covid attendance

# %%
map = folium.Map(location=[40, -95], zoom_start=4)

folium.Choropleth(
    geo_data=geo, 
    data=post_df,
    columns=['STATE_NAME', 'Attendance/Game'],
    key_on='feature.properties.name',
    fill_color='Blues',  # Changed color scheme to blue
    fill_opacity=0.7,  # Increased opacity for better distinction
    line_opacity=0.2,  # Increased line opacity slightly
    nan_fill_color='lightgrey',  # States with no data will appear light grey
    nan_fill_opacity=0.4,  # Light grey slightly transparent
    legend_name="Attendance/Game"
).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a4c2380c74172d1ecfa2d7031d56759 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a4c2380c74172d1ecfa2d7031d56759&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a4c2380c74172d1ecfa2d7031d56759 = L.map(
#                 &quot;map_3a4c2380c74172d1ecfa2d7031d56759&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfd9bde38255e713ebed2e37dc0521d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dfd9bde38255e713ebed2e37dc0521d9.addTo(map_3a4c2380c74172d1ecfa2d7031d56759);
#
#
#             var choropleth_28fa17914a82382c2fc2dc8107abe1b1 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ad665ff9770f75d07ed059b70df5e895_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MS&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;OR&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;lightgrey&quot;, &quot;fillOpacity&quot;: 0.4, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;MN&quot;: case &quot;PA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CO&quot;: case &quot;MA&quot;: case &quot;NY&quot;: case &quot;TX&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;GA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;IL&quot;: case &quot;MO&quot;: case &quot;WA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ad665ff9770f75d07ed059b70df5e895_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ad665ff9770f75d07ed059b70df5e895 = L.geoJson(null, {
#                 onEachFeature: geo_json_ad665ff9770f75d07ed059b70df5e895_onEachFeature,
#
#                 style: geo_json_ad665ff9770f75d07ed059b70df5e895_styler,
#         });
#
#         function geo_json_ad665ff9770f75d07ed059b70df5e895_add (data) {
#             geo_json_ad665ff9770f75d07ed059b70df5e895
#                 .addData(data);
#         }
#             geo_json_ad665ff9770f75d07ed059b70df5e895_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.4991

# %% [markdown]
# ### Analysis

# %% [markdown]
# The teams with the highest attendance are spread across the country. There doesn't seem to be a huge geographic link to attendance in the sense that there are teams with high attendance in most parts of the country. However, one commonality to states with high attendance is a high population in general. California, Texas and New York all have high attendance averages. Interestingly, these state also all have multiple MLB teams. The maps once again visualize the decline in attendance after the pandemic. There are some exceptions. Georgia and Colorado also have high attendance averages despite having relatively smaller cities. Georgia presents one of the most interesting cases - attendance has actually risen in the post-covid world. This is likely attributed to the success of the Atlanta Braves in the last 5 years. A new question that I have from this analysis is how due attendance figures vary when taking into account the capacity of the stadium. Creating a new variable that shows the percentage of attendance based on capacity could reveal different numbers or trends. This analysis is currently likely biased against teams with smaller stadiums - they may actually have relatively high attendance but when compared to large stadiums the data gets muddied.
